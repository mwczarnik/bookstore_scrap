# %%
import pandas
import numpy as np
df = pandas.read_csv("books_data.csv")
df
# Out:
#                                                  Title  \
# 0                         \r\nGerard Wilk. Tancerz\r\n
# 1                       \r\nŻuławski. Wywiad rzeka\r\n
# 2                           \r\nKról, który uciekł\r\n
# 3      \r\n1966. Rok, w którym eksplodowała dekada\r\n
# 4    \r\nKiedy wybuchnie wojna? 1938. Studium kryzy...
# ..                                                 ...
# 433      \r\nŽižek. Przewodnik Krytyki Politycznej\r\n
# 434                           \r\nZwrot polityczny\r\n
# 435                                     \r\nŻałoba\r\n
# 436  \r\nŻołnierze. Protokoły walk, zabijania i umi...
# 437                        \r\nKapitał w XXI wieku\r\n
#
#                                                 Author  \
# 0                                   ['Zofia Rudnicka']
# 1    ['Piotr Marecki', 'Piotr Kletowski', 'Andrzej ...
# 2                                 ['Jędrzej Napiecek']
# 3                                       ['Jon Savage']
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Author', 'Description', 'Publishment_year', 'Num_of_pages',
#        'Bio-description'],
#       dtype='object')

# %%
ls_auth = df['Author']

# %%
from itertools import chain
x = [ type(i) for i in ls_auth]
print(x)
# Out:
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 
# ...
